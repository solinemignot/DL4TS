# %%
pip install tensorflow

# %%
from tslearn.neighbors import KNeighborsTimeSeriesClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Dense
from tslearn.datasets import UCR_UEA_datasets
# Out:
# /Users/mignotsoline/Documents/scolaire/ENSAE/3A/Polytechnique/2eme_semestre/DeepLearning4timeseries/.venv/lib/python3.9/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %% [markdown]
# # Deep Learning for time series - Group 3
# Lataste Alice, Paipetis Spyridon, Roussaux Thomas and Mignot Soline
#
# ## 1st step : Decent baseline

# %%
ds = UCR_UEA_datasets()
X_train, y_train, X_test, y_test = ds.load_dataset("LSST")

# %%
model = KNeighborsTimeSeriesClassifier(n_neighbors=1, metric="dtw")
model.fit(X_train, y_train)
accuracy = model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = KNeighborsTimeSeriesClassifier(n_neighbors=1, metric="dtw")
#       2 model.fit(X_train, y_train)
# ----> 3 accuracy = model.score(X_test, y_test)
#
# File ~/Documents/scolaire/ENSAE/3A/Polytechnique/2eme_semestre/DeepLearning4timeseries/.venv/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:446, in KNeighborsClassifier.score(self, X, y, sample_weight)
#     417 def score(self, X, y, sample_weight=None):
#     418     """
#     419     Return the mean accuracy on the given test data and labels.
#     420
#    (...)
#     444         Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     445     """
# --> 446     return super().score(X, y, sample_weight)
#
# ...

# %%
accuracy

# %%
model2 = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    GlobalAveragePooling1D(),
    Dense(len(np.unique(y_train)), activation='softmax')
])
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model2.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
accuracy2 = model2.score(X_test, y_test)

# %%
accuracy2
